# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from pycaret.classification import *


df = pd.read_csv('/content/workingdata.csv', index_col='customerID')

# Cleaning Datas
# Replace infinite values with NaN
df = df.replace([np.inf, -np.inf], np.nan)
if 'Unnamed: 0' in df.columns:
    df.drop(['Unnamed: 0'], axis=1, inplace=True)

# Drop rows with missing values in the 'Churn' column
df.dropna(subset=['Churn'], inplace=True)

# Proceed with PyCaret setup
automl = setup(data=df, target='Churn')
# Out:
# <style type="text/css">
# #T_20dbd_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_20dbd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20dbd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_20dbd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20dbd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20dbd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_20dbd_row0_col1" class="data row0 col1" >5470</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20dbd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_20dbd_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20dbd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_20dbd_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20dbd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_20dbd_row3_col1" class="data row3 col1" >(7032, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20dbd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_20dbd_row4_col1" class="data row4 col1" >(7032, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20dbd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_20dbd_row5_col1" class="data row5 col1" >(4922, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20dbd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_20dbd_row6_col1" class="data row6 col1" >(2110, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20dbd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_20dbd_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20dbd_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_20dbd_row8_col1" class="data row8 col1" >55.1%</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20dbd_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_20dbd_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_20dbd_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_20dbd_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_20dbd_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_20dbd_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_20dbd_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_20dbd_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_20dbd_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_20dbd_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_20dbd_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_20dbd_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_20dbd_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_20dbd_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_20dbd_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_20dbd_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_20dbd_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_20dbd_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_20dbd_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_20dbd_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_20dbd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_20dbd_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_20dbd_row19_col1" class="data row19 col1" >fd66</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_7f68c th {
#   text-align: left;
# }
# #T_7f68c_row0_col0, #T_7f68c_row0_col3, #T_7f68c_row0_col4, #T_7f68c_row0_col5, #T_7f68c_row0_col7, #T_7f68c_row1_col0, #T_7f68c_row1_col1, #T_7f68c_row1_col2, #T_7f68c_row1_col3, #T_7f68c_row1_col4, #T_7f68c_row1_col5, #T_7f68c_row1_col6, #T_7f68c_row1_col7, #T_7f68c_row2_col0, #T_7f68c_row2_col1, #T_7f68c_row2_col2, #T_7f68c_row2_col3, #T_7f68c_row2_col4, #T_7f68c_row2_col5, #T_7f68c_row2_col6, #T_7f68c_row2_col7, #T_7f68c_row3_col0, #T_7f68c_row3_col1, #T_7f68c_row3_col2, #T_7f68c_row3_col3, #T_7f68c_row3_col4, #T_7f68c_row3_col5, #T_7f68c_row3_col6, #T_7f68c_row3_col7, #T_7f68c_row4_col0, #T_7f68c_row4_col1, #T_7f68c_row4_col2, #T_7f68c_row4_col3, #T_7f68c_row4_col5, #T_7f68c_row4_col6, #T_7f68c_row4_col7, #T_7f68c_row5_col0, #T_7f68c_row5_col1, #T_7f68c_row5_col2, #T_7f68c_row5_col3, #T_7f68c_row5_col4, #T_7f68c_row5_col5, #T_7f68c_row5_col6, #T_7f68c_row5_col7, #T_7f68c_row6_col0, #T_7f68c_row6_col1, #T_7f68c_row6_col2, #T_7f68c_row6_col3, #T_7f68c_row6_col4, #T_7f68c_row6_col5, #T_7f68c_row6_col6, #T_7f68c_row6_col7, #T_7f68c_row7_col0, #T_7f68c_row7_col1, #T_7f68c_row7_col2, #T_7f68c_row7_col3, #T_7f68c_row7_col4, #T_7f68c_row7_col5, #T_7f68c_row7_col6, #T_7f68c_row7_col7, #T_7f68c_row8_col0, #T_7f68c_row8_col1, #T_7f68c_row8_col2, #T_7f68c_row8_col3, #T_7f68c_row8_col4, #T_7f68c_row8_col5, #T_7f68c_row8_col6, #T_7f68c_row8_col7, #T_7f68c_row9_col0, #T_7f68c_row9_col1, #T_7f68c_row9_col2, #T_7f68c_row9_col3, #T_7f68c_row9_col4, #T_7f68c_row9_col5, #T_7f68c_row9_col6, #T_7f68c_row9_col7, #T_7f68c_row10_col0, #T_7f68c_row10_col1, #T_7f68c_row10_col2, #T_7f68c_row10_col3, #T_7f68c_row10_col4, #T_7f68c_row10_col5, #T_7f68c_row10_col6, #T_7f68c_row10_col7, #T_7f68c_row11_col0, #T_7f68c_row11_col1, #T_7f68c_row11_col2, #T_7f68c_row11_col3, #T_7f68c_row11_col4, #T_7f68c_row11_col5, #T_7f68c_row11_col6, #T_7f68c_row11_col7, #T_7f68c_row12_col0, #T_7f68c_row12_col1, #T_7f68c_row
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=4488, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_60521" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60521_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_60521_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_60521_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_60521_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_60521_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_60521_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_60521_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_60521_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60521_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60521_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_60521_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_60521_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_60521_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_60521_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_60521_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_60521_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_60521_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#             Unnamed: 0  tenure  PhoneService  Contract  PaymentMethod  \
# customerID
# 8361-LTMKD        7041       4             1         0              1
#
#             MonthlyCharges  TotalCharges  tenure_contract_ratio  \
# customerID
# 8361-LTMKD       74.400002    306.600006                    NaN
#
#             TotalCharges_tenure_ratio  Churn  prediction_label  \
# customerID
# 8361-LTMKD                  76.650002      1                 1
#
#             prediction_score
# customerID
# 8361-LTMKD             0.594

# %%
# Save the model to disk
save_model(best_model, 'SN_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Unnamed: 0', 'tenure',
#                                               'PhoneService', 'Contract',
#                                               'PaymentMethod', 'MonthlyCharges',
#                                               'TotalCharges',
#                                               'tenure_contract_ratio',
#                                               'TotalCharges_tenure_ratio'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=Fal...
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=4488,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'SN_model.pkl')

# %%
import pickle

with open('SN_model.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('SN_model.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
new_data = df.iloc[-2:-1].copy()
loaded_model = load_model('SN_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# **Summary:**
# An attempt was made to use the pycaret to find a ML algorithm to fit in the data. Different metrics were utilized for finding the best model among which I have utilized the regression. The model SN_model was saved to the disk along with a python script. The error arised while predicting with the new churn data set as some of the columns were not fitted. The python script is then subjected to be uploaded in the GitHub repository.
